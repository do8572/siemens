# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from rankfm.rankfm import RankFM
from rankfm.evaluation import hit_rate, reciprocal_rank, discounted_cumulative_gain, precision, recall, diversity

# %%
df = pd.read_csv('transaction_history.csv')
# df['prod'] = df["prod"].replace(regex='_.{4}$', value="")       # use product and family info only
# df['prod'] = df["prod"].replace(regex='_.{4}_.{4}$', value="")  # use family info only
# df

# %%
df.domestic = pd.factorize(df.domestic)[0]
df = pd.get_dummies(df, dummy_na=True, columns=['state', 'ind_code','ind_seg_code'])
# df

# %%
interactions = pd.DataFrame(df.iloc[:, [1,2,4,0]])
interactions = interactions.rename(columns={"customer": "user_id", "prod": "item_id"})
# interactions

# %%
user_features = df.iloc[:,1:]
user_features = user_features.drop(['new_orders', 'prod'], axis=1)
user_features = user_features.rename(columns={"customer": "user_id"})
user_features = user_features.drop_duplicates('user_id')
# user_features

# %%
test_size = 125
k = 5
model = RankFM(factors=20, loss='warp', max_samples=20, alpha=0.01, 
               sigma=0.1, learning_rate=0.10, learning_schedule='invscaling')

avg_base = []
avg_same = []
avg_diff = []
           
for i in range(6):
    train_mask = (df.day>test_size*i) & (df.day<=500+test_size*i)
    valid_mask = (df.day>500+test_size*i) & (df.day<=500+test_size*(i+1))
    
    interactions_train = interactions[train_mask][['user_id', 'item_id']]
    interactions_valid = interactions[valid_mask][['user_id', 'item_id']]
    
    train_users = np.sort(interactions_train.user_id.unique())
    valid_users = np.sort(interactions_valid.user_id.unique())
    user_features_train = user_features[user_features.user_id.isin(train_users)]
    
    print("train users: {}".format(len(train_users)))
    print("valid users: {}".format(len(valid_users)))

    model.fit(interactions_train, user_features=user_features_train, epochs=20, verbose=True)
    
    test_user_items = interactions_valid.groupby('user_id')['item_id'].apply(set).to_dict()
    test_user_items = {key: val for key, val in test_user_items.items() if key in set(train_users)}
    
    most_popular = interactions_train.groupby('item_id')['user_id'].count().sort_values(ascending=False)[:k]

    base_hrt = np.mean([int(len(set(most_popular.index) & set(val)) > 0)                       for key, val in test_user_items.items()])

    print("number of test users: {}".format(len(test_user_items)))
    print("baseline hit rate: {:.3f}".format(base_hrt))
    avg_base.append(base_hrt)
    
    model_hit_rate = hit_rate(model, interactions_valid, k=k)
    print("hit_rate_same: {:.3f}".format(model_hit_rate))
    avg_same.append(model_hit_rate)

    model_hit_rate = hit_rate(model, interactions_valid, k=k, filter_previous=True)
    print("hit_rate_diff: {:.3f}".format(model_hit_rate))
    avg_diff.append(model_hit_rate)
    print()
    
print("mean baseline:", np.mean(avg_base))
print("mean same:", np.mean(avg_same))
print("mean diff:", np.mean(avg_diff))
# Out:
# train users: 2113
# valid users: 1400
#
# training epoch: 0
# log likelihood: -31410.19921875
#
# training epoch: 1
# log likelihood: -26836.390625
#
# training epoch: 2
# log likelihood: -25651.25
#
# training epoch: 3
# log likelihood: -25049.30078125
#
# training epoch: 4
# log likelihood: -24649.41015625
#
# training epoch: 5
# log likelihood: -24445.939453125
#
# training epoch: 6
# log likelihood: -24057.7109375
#
# training epoch: 7
# log likelihood: -23948.669921875
#
# training epoch: 8
# log likelihood: -23761.919921875
#
# training epoch: 9
# log likelihood: -23614.669921875
#
# training epoch: 10
# log likelihood: -23602.7109375
#
# training epoch: 11
# log likelihood: -23453.599609375
#
# training epoch: 12
# log likelihood: -23396.41015625
#
# training epoch: 13
# log likelihood: -23243.189453125
#
# training epoch: 14
# log likelihood: -23306.779296875
#
# training epoch: 15
# log likelihood: -23153.51953125
#
# training epoch: 16
# log likelihood: -23076.91015625
#
# training epoch: 17
# log likelihood: -23101.990234375
#
# training epoch: 18
# log likelihood: -23002.73046875
#
# training epoch: 19
# log likelihood: -22924.990234375
# number of test users: 1270
# baseline hit rate: 0.940
# hit_rate_same: 0.968
# hit_rate_diff: 0.252
#
# train users: 2154
# valid users: 1434
#
# training epoch: 0
# log likelihood: -30942.279296875
#
# training epoch: 1
# log likelihood: -26386.259765625
#
# training epoch: 2
# log likelihood: -25381.470703125
#
# training epoch: 3
# log likelihood: -24781.58984375
#
# training epoch: 4
# log likelihood: -24417.990234375
#
# training epoch: 5
# log likelihood: -24097.119140625
#
# training epoch: 6
# log likelihood: -23880.58984375
#
# training epoch: 7
# log likelihood: -23674.830078125
#
# training epoch: 8
# log likelihood: -23555.220703125
#
# training epoch: 9
# log likelihood: -23401.1796875
#
# training epoch: 10
# log likelihood: -23256.01953125
#
# training epoch: 11
# log likelihood: -23141.9296875
#
# training epoch: 12
# log likelihood: -22991.80078125
#
# training epoch: 13
# log likelihood: -22997.91015625
#
# training epoch: 14
# log likelihood: -22926.7109375
#
# training epoch: 15
# log likelihood: -22903.9609375
#
# training epoch: 16
# log likelihood: -22754.58984375
#
# training epoch: 17
# log likelihood: -22739.26953125
#
# training epoch: 18
# log likelihood: -22670.119140625
#
# training epoch: 19
# log likelihood: -22645.44921875
# number of test users: 1286
# baseline hit rate: 0.931
# hit_rate_same: 0.967
# hit_rate_diff: 0.281
#
# train users: 2166
# valid users: 1395
#
# training epoch: 0
# log likelihood: -30168.310546875
#
# training epoch: 1
# log likelihood: -25540.060546875
#
# training epoch: 2
# log likelihood: -24432.4296875
#
# training epoch: 3
# log likelihood: -23834.740234375
#
# training epoch: 4
# log likelihood: -23460.619140625
#
# training epoch: 5
# log likelihood: -23117.880859375
#
# training epoch: 6
# log likelihood: -22898.119140625
#
# training epoch: 7
# log likelihood: -22656.23046875
#
# training epoch: 8
# log likelihood: -22507.900390625
#
# training epoch: 9
# log likelihood: -22443.740234375
#
# training epoch: 10
# log likelihood: -22281.7109375
#
# training epoch: 11
# log likelihood: -22211.91015625
#
# training epoch: 12
# log likelihood: -22050.359375
#
# training epoch: 13
# log likelihood: -21980.75
#
# training epoch: 14
# log likelihood: -21957.580078125
#
# training epoch: 15
# log likelihood: -21888.490234375
#
# training epoch: 16
# log likelihood: -21844.3203125
#
# training epoch: 17
# log likelihood: -21707.55078125
#
# training epoch: 18
# log likelihood: -21707.189453125
#
# training epoch: 19
# log likelihood: -21624.48046875
# number of test users: 1266
# baseline hit rate: 0.935
# hit_rate_same: 0.968
# hit_rate_diff: 0.287
#
# train users: 2173
# valid users: 1485
#
# training epoch: 0
# log likelihood: -29689.75
#
# training epoch: 1
# log likelihood: -25113.76953125
#
# training epoch: 2
# log likelihood: -24021.330078125
#
# training epoch: 3
# log likelihood: -23483.98046875
#
# training epoch: 4
# log likelihood: -23115.76953125
#
# training epoch: 5
# log likelihood: -22801.8203125
#
# training epoch: 6
# log likelihood: -22599.41015625
#
# training epoch: 7
# log likelihood: -22354.279296875
#
# training epoch: 8
# log likelihood: -22238.48046875
#
# training epoch: 9
# log likelihood: -22139.080078125
#
# training epoch: 10
# log likelihood: -22026.470703125
#
# training epoch: 11
# log likelihood: -21888.390625
#
# training epoch: 12
# log likelihood: -21791.970703125
#
# training epoch: 13
# log likelihood: -21650.19921875
#
# training epoch: 14
# log likelihood: -21650.4609375
#
# training epoch: 15
# log likelihood: -21514.900390625
#
# training epoch: 16
# log likelihood: -21527.640625
#
# training epoch: 17
# log likelihood: -21478.470703125
#
# training epoch: 18
# log likelihood: -21341.220703125
#
# training epoch: 19
# log likelihood: -21337.66015625
# number of test users: 1358
# baseline hit rate: 0.936
# hit_rate_same: 0.971
# hit_rate_diff: 0.256
#
# train users: 2169
# valid users: 1420
#
# training epoch: 0
# log likelihood: -31640.779296875
#
# training epoch: 1
# log likelihood: -26657.890625
#
# training epoch: 2
# log likelihood: -25516.23046875
#
# training epoch: 3
# log likelihood: -24868.130859375
#
# training epoch: 4
# log likelihood: -24447.140625
#
# training epoch: 5
# log likelihood: -24151.16015625
#
# training epoch: 6
# log likelihood: -23914.5
#
# training epoch: 7
# log likelihood: -23588.640625
#
# training epoch: 8
# log likelihood: -23546.970703125
#
# training epoch: 9
# log likelihood: -23395.69921875
#
# training epoch: 10
# log likelihood: -23293.810546875
#
# training epoch: 11
# log likelihood: -23154.369140625
#
# training epoch: 12
# log likelihood: -22982.189453125
#
# training epoch: 13
# log likelihood: -23057.169921875
#
# training epoch: 14
# log likelihood: -22903.490234375
#
# training epoch: 15
# log likelihood: -22842.080078125
#
# training epoch: 16
# log likelihood: -22798.419921875
#
# training epoch: 17
# log likelihood: -22740.650390625
#
# training epoch: 18
# log likelihood: -22645.5
#
# training epoch: 19
# log likelihood: -22652.630859375
# number of test users: 1295
# baseline hit rate: 0.937
# hit_rate_same: 0.967
# hit_rate_diff: 0.242
#
# train users: 2172
# valid users: 1440
#
# training epoch: 0
# log likelihood: -33164.6484375
#
# training epoch: 1
# log likelihood: -27934.94921875
#
# training epoch: 2
# log likelihood: -26825.640625
#
# training epoch: 3
# log likelihood: -26110.08984375
#
# training epoch: 4
# log likelihood: -25707.05078125
#
# training epoch: 5
# log likelihood: -25394.359375
#
# training epoch: 6
# log likelihood: -25082.740234375
#
# training epoch: 7
# log likelihood: -24975.76953125
#
# training epoch: 8
# log likelihood: -24761.849609375
#
# training epoch: 9
# log likelihood: -24613.029296875
#
# training epoch: 10
# log likelihood: -24568.05078125
#
# training epoch: 11
# log likelihood: -24439.640625
#
# training epoch: 12
# log likelihood: -24419.169921875
#
# training epoch: 13
# log likelihood: -24218.1796875
#
# training epoch: 14
# log likelihood: -24211.349609375
#
# training epoch: 15
# log likelihood: -24166.859375
#
# training epoch: 16
# log likelihood: -24089.0703125
#
# training epoch: 17
# log likelihood: -24036.609375
#
# training epoch: 18
# log likelihood: -24052.080078125
#
# training epoch: 19
# log likelihood: -23956.890625
# number of test users: 1314
# baseline hit rate: 0.941
# hit_rate_same: 0.973
# hit_rate_diff: 0.248
#
# mean baseline: 0.9366991242061653
# mean same: 0.9691503312243581
# mean diff: 0.26091750682920734
